# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
df_noduplicates = df.drop_duplicates()

# %%
df_noduplicates.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_noduplicates.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df1 = df_noduplicates.loc[df_noduplicates['Type']=='Paid']

# %%
#df1['Price'] = df1['Price'].replace('$','')

# %% [markdown]
# #### modfiyng the installs and Price columns

# %%
final_df = df1.drop(df1.loc[df1['Installs']=='Free'].index)
final_df = final_df.reset_index()
final_df = final_df.drop(columns='index')

#final_df = final_df.drop(final_df['in'])
special_characters=[',','.','+','$','M','k']
shapes = final_df.shape
lengths = shapes[0]
type(lengths)
for i in range(0,lengths):
    for a in special_characters:
        final_df.loc[i,'Installs'] = final_df.loc[i,'Installs'].replace(a,"")
        final_df.loc[i,'Price'] = final_df.loc[i,'Price'].replace(a,"")
        final_df.loc[i,'Size'] = final_df.loc[i,'Size'].replace(a,"")
    final_df.loc[i,'Installs'] = float(final_df.loc[i,'Installs']) 
    final_df.loc[i,'Price'] = float(final_df.loc[i,'Price'])

# %%
final_df
# Out:
#                                                App            Category  \
# 0    TurboScan: scan documents and receipts in PDF            BUSINESS
# 1                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 2                               Puffin Browser Pro       COMMUNICATION
# 3                        Moco+ - Chat, Meet People              DATING
# 4                                       Calculator              DATING
# ..                                             ...                 ...
# 760                                    FP VoiceBot              FAMILY
# 761                                Fast Tract Diet  HEALTH_AND_FITNESS
# 762                        Trine 2: Complete Story                GAME
# 763                                   sugar, sugar              FAMILY
# 764                           Word Search Tab 1 FR              FAMILY
#
#      Rating Reviews                Size  Installs  Type   Price  \
# 0       4.7   11442                  68  100000.0  Paid   499.0
# 1       4.8   10295                  39  100000.0  Paid   499.0
# 2       4.0   18247  Varies with device  100000.0  Paid   399.0
# 3       4.2    1545  Varies with device   10000.0  Paid   399.0
# 4       2.6      57                  62    1000.0  Paid   699.0
# ..      ...     ...                 ...       ...   ...     ...
# 760     NaN      17                 157     100.0  Paid    99.0
# 761     4.4      35                  24    1000.0  Paid   799.0
# 762     3.8     252                  11   10000.0  Paid  1699.0
# 763     4.2    1405                  95   10000.0  Paid   120.0
# 764     NaN       0                1020      50.0  Paid   104.0
#
#     Content Rating            Genres       Last Updated  Current Ver  \
# 0         Everyone          Business     March 25, 2018        1.5.2
# 1         Everyone          Business     April 11, 2017        3.4.6
# 2         Everyone     Communication       July 5, 2018  7.5.3.20547
# 3       Mature 17+            Dating      June 19, 2018      2.6.139
# 4         Everyone            Dating   October 25, 2017        1.1.6
# ..             ...               ...                ...          ...
# 760     Mature 17+     Entertainment  November 25, 2015          1.2
# 761       Everyone  Health & Fitness     August 8, 2018        1.9.3
# 762           Teen            Action  February 27, 2015         2.22
# 763       Everyone            Puzzle       June 5, 2018          2.7
# 764       Everyone            Puzzle   February 6, 2012          1.1
#
#     Android Ver
# 0    4.0 and up
# 1    3.0 and up
# 2    4.1 and up
# 3    4.1 and up
# 4    4.0 and up
# ..          ...
# 760  2.1 and up
# 761  4.2 and up
# 762  5.0 and up
# 763  2.3 and up
# 764  3.0 and up
#
# [765 rows x 13 columns]

# %%
#final_df = final_df.drop(final_df['in'])
special_characters=['k','Varies with device']
shapes = final_df.shape
lengths = shapes[0]
type(lengths)
for i in range(0,lengths):
    for a in special_characters:
        if a ==special_characters[0]:
            final_df.loc[i,'Size'] = final_df.loc[i,'Size'].replace(a,'')
            #final_df.loc[i,'Size'] = final_df.loc[i,'Size']/1000
        else:
            final_df.loc[i,'Size'] = final_df.loc[i,'Size'].replace(a,0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_302787/1806334967.py in <module>
#      10             #final_df.loc[i,'Size'] = final_df.loc[i,'Size']/1000
#      11         else:
# ---> 12             final_df.loc[i,'Size'] = final_df.loc[i,'Size'].replace(a,0)
#
# TypeError: replace() argument 2 must be str, not int

# %%
final_df
# Out:
#                                                App            Category  \
# 0    TurboScan: scan documents and receipts in PDF            BUSINESS
# 1                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 2                               Puffin Browser Pro       COMMUNICATION
# 3                        Moco+ - Chat, Meet People              DATING
# 4                                       Calculator              DATING
# ..                                             ...                 ...
# 760                                    FP VoiceBot              FAMILY
# 761                                Fast Tract Diet  HEALTH_AND_FITNESS
# 762                        Trine 2: Complete Story                GAME
# 763                                   sugar, sugar              FAMILY
# 764                           Word Search Tab 1 FR              FAMILY
#
#      Rating Reviews  Size  Installs  Type   Price Content Rating  \
# 0       4.7   11442    68  100000.0  Paid   499.0       Everyone
# 1       4.8   10295    39  100000.0  Paid   499.0       Everyone
# 2       4.0   18247     0  100000.0  Paid   399.0       Everyone
# 3       4.2    1545     0   10000.0  Paid   399.0     Mature 17+
# 4       2.6      57    62    1000.0  Paid   699.0       Everyone
# ..      ...     ...   ...       ...   ...     ...            ...
# 760     NaN      17   157     100.0  Paid    99.0     Mature 17+
# 761     4.4      35    24    1000.0  Paid   799.0       Everyone
# 762     3.8     252    11   10000.0  Paid  1699.0           Teen
# 763     4.2    1405    95   10000.0  Paid   120.0       Everyone
# 764     NaN       0  1020      50.0  Paid   104.0       Everyone
#
#                Genres       Last Updated  Current Ver Android Ver
# 0            Business     March 25, 2018        1.5.2  4.0 and up
# 1            Business     April 11, 2017        3.4.6  3.0 and up
# 2       Communication       July 5, 2018  7.5.3.20547  4.1 and up
# 3              Dating      June 19, 2018      2.6.139  4.1 and up
# 4              Dating   October 25, 2017        1.1.6  4.0 and up
# ..                ...                ...          ...         ...
# 760     Entertainment  November 25, 2015          1.2  2.1 and up
# 761  Health & Fitness     August 8, 2018        1.9.3  4.2 and up
# 762            Action  February 27, 2015         2.22  5.0 and up
# 763            Puzzle       June 5, 2018          2.7  2.3 and up
# 764            Puzzle   February 6, 2012          1.1  3.0 and up
#
# [765 rows x 13 columns]

# %%
final_df['Size'] = final_df['Size'].replace('Varies with device',0)

# %%
final_df = final_df.astype({'Installs':'float','Price':'float','Size':'float'})
#final_df = final_df.astype({'Installs':'float','Price':'float','Size':'float'})

# %%
final_df['Revenue'] = final_df['Installs'] * final_df['Price']

# %%
final_df
# Out:
#                                                App            Category  \
# 0    TurboScan: scan documents and receipts in PDF            BUSINESS
# 1                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 2                               Puffin Browser Pro       COMMUNICATION
# 3                        Moco+ - Chat, Meet People              DATING
# 4                                       Calculator              DATING
# ..                                             ...                 ...
# 760                                    FP VoiceBot              FAMILY
# 761                                Fast Tract Diet  HEALTH_AND_FITNESS
# 762                        Trine 2: Complete Story                GAME
# 763                                   sugar, sugar              FAMILY
# 764                           Word Search Tab 1 FR              FAMILY
#
#      Rating Reviews    Size  Installs  Type   Price Content Rating  \
# 0       4.7   11442    68.0  100000.0  Paid   499.0       Everyone
# 1       4.8   10295    39.0  100000.0  Paid   499.0       Everyone
# 2       4.0   18247     0.0  100000.0  Paid   399.0       Everyone
# 3       4.2    1545     0.0   10000.0  Paid   399.0     Mature 17+
# 4       2.6      57    62.0    1000.0  Paid   699.0       Everyone
# ..      ...     ...     ...       ...   ...     ...            ...
# 760     NaN      17   157.0     100.0  Paid    99.0     Mature 17+
# 761     4.4      35    24.0    1000.0  Paid   799.0       Everyone
# 762     3.8     252    11.0   10000.0  Paid  1699.0           Teen
# 763     4.2    1405    95.0   10000.0  Paid   120.0       Everyone
# 764     NaN       0  1020.0      50.0  Paid   104.0       Everyone
#
#                Genres       Last Updated  Current Ver Android Ver     Revenue
# 0            Business     March 25, 2018        1.5.2  4.0 and up  49900000.0
# 1            Business     April 11, 2017        3.4.6  3.0 and up  49900000.0
# 2       Communication       July 5, 2018  7.5.3.20547  4.1 and up  39900000.0
# 3              Dating      June 19, 2018      2.6.139  4.1 and up   3990000.0
# 4              Dating   October 25, 2017        1.1.6  4.0 and up    699000.0
# ..                ...                ...          ...         ...         ...
# 760     Entertainment  November 25, 2015          1.2  2.1 and up      9900.0
# 761  Health & Fitness     August 8, 2018        1.9.3  4.2 and up    799000.0
# 762            Action  February 27, 2015         2.22  5.0 and up  16990000.0
# 763            Puzzle       June 5, 2018          2.7  2.3 and up   1200000.0
# 764            Puzzle   February 6, 2012          1.1  3.0 and up      5200.0
#
# [765 rows x 14 columns]

# %% [markdown]
# ### Top apps by revenues

# %% [markdown]
# #### Top Revenue from apps

# %%
Top_apps_by_revenues = final_df.sort_values(by='Revenue',ascending=False).reset_index().drop(columns='index')

# %%
Top_apps_by_revenues.loc[Top_apps_by_revenues['App']=='Minecraft']
# Out:
#          App Category  Rating  Reviews  Size    Installs  Type  Price  \
# 0  Minecraft   FAMILY     4.5  2376564   0.0  10000000.0  Paid  699.0
# 1  Minecraft   FAMILY     4.5  2375336   0.0  10000000.0  Paid  699.0
#
#   Content Rating                     Genres   Last Updated Current Ver  \
# 0   Everyone 10+  Arcade;Action & Adventure  July 24, 2018     1.5.2.1
# 1   Everyone 10+  Arcade;Action & Adventure  July 24, 2018     1.5.2.1
#
#           Android Ver       Revenue
# 0  Varies with device  6.990000e+09
# 1  Varies with device  6.990000e+09

# %%
Top_apps_by_revenues = Top_apps_by_revenues[['App','Revenue']].head(13)

# %%
Top_apps_by_revenues
# Out:
#                               App       Revenue
# 0                       Minecraft  6.990000e+09
# 1                       Minecraft  6.990000e+09
# 2                       I am rich  3.999900e+09
# 3               I Am Rich Premium  1.999950e+09
# 4                   Hitman Sniper  9.900000e+08
# 5   Grand Theft Auto: San Andreas  6.990000e+08
# 6         Sleep as Android Unlock  5.990000e+08
# 7             Facetune - For Free  5.990000e+08
# 8             DraStic DS Emulator  4.990000e+08
# 9        I'm Rich - Trump Edition  4.000000e+08
# 10                     💎 I'm rich  3.999900e+08
# 11                 I am Rich Plus  3.999900e+08
# 12                      I Am Rich  3.899900e+08

# %% [markdown]
# #### Looking at reveues beeing generated by most apps

# %%
Apps_per_revenue =final_df.groupby('Revenue')['App'].count().to_frame().sort_values(by='App',ascending=False).head(10)

# %%
Apps_per_revenue
# Out:
#             App
# Revenue
# 2990000.0    27
# 99000.0      25
# 29900000.0   24
# 990.0        24
# 9900.0       22
# 299000.0     16
# 990000.0     15
# 1990000.0    15
# 199000.0     14
# 49900000.0   14

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style="white", context="talk")
sns.barplot(data=Apps_per_revenue ,y=Apps_per_revenue['App'], x=Apps_per_revenue.index ,)
plt.title('Most Categories by Installs '.title())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Looking at the highest revenues with the number of apps beeing genearted by them

# %%
High_revenue_apps =final_df.groupby('Revenue')['App'].count().to_frame().sort_index(ascending=False).head(10)

# %%
High_revenue_apps
# Out:
#               App
# Revenue
# 6.990000e+09    2
# 3.999900e+09    1
# 1.999950e+09    1
# 9.900000e+08    1
# 6.990000e+08    1
# 5.990000e+08    2
# 4.990000e+08    1
# 4.000000e+08    1
# 3.999900e+08    2
# 3.899900e+08    1

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style="white", context="talk")
sns.barplot(data=High_revenue_apps ,y=High_revenue_apps['App'], x=High_revenue_apps.index ,)
plt.title('Most Categories by Installs '.title())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Looking at most prevalent categories

# %%
category1 = final_df.groupby('Category')['Revenue'].sum().to_frame()

# %%
#category1

# %%
category1 = category1.sort_values(by='Revenue').tail(10)

# %%
category1
# Out:
#                       Revenue
# Category
# PRODUCTIVITY     4.313375e+08
# SPORTS           4.706212e+08
# TOOLS            5.464821e+08
# PERSONALIZATION  7.786948e+08
# MEDICAL          8.456536e+08
# PHOTOGRAPHY      8.942768e+08
# FINANCE          2.572668e+09
# GAME             4.098764e+09
# LIFESTYLE        5.758394e+09
# FAMILY           1.857803e+10

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style="white", context="talk")
sns.barplot(data=category1 ,y=category1['Revenue'], x=category1.index ,)
plt.title('Most Categories by Installs '.title())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Looking at top apps by revenue and comparing them to the mean size

# %%
final_df.groupby('Size')['App'].count().to_frame()
# Out:
#         App
# Size
# 0.0      74
# 10.0      8
# 11.0     17
# 12.0     22
# 13.0     10
# ...     ...
# 951.0     1
# 954.0     1
# 957.0     1
# 965.0     1
# 1020.0    1
#
# [140 rows x 1 columns]

# %%
mean_size = final_df['Size'].mean()

# %%
size_exploration = final_df.copy()

# %%
size_exploration['Size'] = size_exploration['Size'].replace(0,mean_size)

# %%
mean_size
# Out:
# 68.13464052287581

# %%
Apps_list =['Minecraft','I am rich','I Am Rich Premium','Hitman Sniper','Grand Theft Auto: San Andreas',
            'Sleep as Android Unlock','Facetune - For Free','DraStic DS Emulator','I\'m Rich-Trump Edition',
           '💎 I\'m rich','I am Rich Plus 	']

# %%
Top_apps_by_size = size_exploration.loc[size_exploration['App'].isin(Top_apps_by_revenues.App)]

# %%
Top_apps_by_size
# Out:
#                                App     Category  Rating  Reviews        Size  \
# 54                       Minecraft       FAMILY     4.5  2376564   68.134641
# 122            Facetune - For Free  PHOTOGRAPHY     4.4    49553   48.000000
# 143                  Hitman Sniper         GAME     4.6   408292   29.000000
# 180                      Minecraft       FAMILY     4.5  2375336   68.134641
# 182                     💎 I'm rich    LIFESTYLE     3.8      718   26.000000
# 183       I'm Rich - Trump Edition    LIFESTYLE     3.6      275   73.000000
# 309                      I am rich    LIFESTYLE     3.8     3547   18.000000
# 310                 I am Rich Plus       FAMILY     4.0      856   87.000000
# 312              I Am Rich Premium      FINANCE     4.1     1867   47.000000
# 320                      I Am Rich       FAMILY     3.6      217   49.000000
# 340        Sleep as Android Unlock    LIFESTYLE     4.5    23966  872.000000
# 494  Grand Theft Auto: San Andreas         GAME     4.4   348962   26.000000
# 621            DraStic DS Emulator         GAME     4.6    87766   12.000000
#
#        Installs  Type    Price Content Rating                     Genres  \
# 54   10000000.0  Paid    699.0   Everyone 10+  Arcade;Action & Adventure
# 122   1000000.0  Paid    599.0       Everyone                Photography
# 143  10000000.0  Paid     99.0     Mature 17+                     Action
# 180  10000000.0  Paid    699.0   Everyone 10+  Arcade;Action & Adventure
# 182     10000.0  Paid  39999.0       Everyone                  Lifestyle
# 183     10000.0  Paid  40000.0       Everyone                  Lifestyle
# 309    100000.0  Paid  39999.0       Everyone                  Lifestyle
# 310     10000.0  Paid  39999.0       Everyone              Entertainment
# 312     50000.0  Paid  39999.0       Everyone                    Finance
# 320     10000.0  Paid  38999.0       Everyone              Entertainment
# 340   1000000.0  Paid    599.0       Everyone                  Lifestyle
# 494   1000000.0  Paid    699.0     Mature 17+                     Action
# 621   1000000.0  Paid    499.0       Everyone                     Action
#
#           Last Updated Current Ver         Android Ver       Revenue
# 54       July 24, 2018     1.5.2.1  Varies with device  6.990000e+09
# 122      July 25, 2018       1.3.1          4.1 and up  5.990000e+08
# 143      July 12, 2018  1.7.110758          4.1 and up  9.900000e+08
# 180      July 24, 2018     1.5.2.1  Varies with device  6.990000e+09
# 182     March 11, 2018       1.0.0          4.4 and up  3.999900e+08
# 183        May 3, 2018       1.0.1          4.1 and up  4.000000e+08
# 309   January 12, 2018         2.0        4.0.3 and up  3.999900e+09
# 310       May 19, 2018         3.0          4.4 and up  3.999900e+08
# 312  November 12, 2017         1.6          4.0 and up  1.999950e+09
# 320      June 22, 2018         1.5          4.2 and up  3.899900e+08
# 340      June 27, 2018    20180608          4.0 and up  5.990000e+08
# 494     March 21, 2015        1.08          3.0 and up  6.990000e+08
# 621      July 19, 2016   r2.5.0.3a          2.3 and up  4.990000e+08

# %%
plt.figure(figsize=(15,5))
sns.set_theme(style="white", context="talk")
sns.barplot(data=Top_apps_by_size ,x=Top_apps_by_size['App'], y=Top_apps_by_size['Size'] ,)
plt.title('Most  Categories by installs -Free '.title())
plt.xticks(rotation=90)
plt.show()
# Out:
# /home/julian/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128142 (\N{GEM STONE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
