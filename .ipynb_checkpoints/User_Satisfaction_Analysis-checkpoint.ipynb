# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('googleplaystore_user_reviews.csv')

# %%
df_copy = df.copy()

# %%
df_copy
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
df_copy.groupby('App')['App'].count().to_frame().head(19)
# Out:
#                                                     App
# App
# 10 Best Foods for You                               200
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                     40
# 11st                                                 40
# 1800 Contacts - Lens Store                           80
# 1LINE – One Line with One Touch                      40
# 2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif     40
# 21-Day Meditation Experience                         80
# 2Date Dating App, Love and matching                  40
# 2GIS: directory & navigator                          40
# 2RedBeans                                            40
# 2ndLine - Second Phone Number                        40
# 30 Day Fitness Challenge - Workout at Home           40
# 365Scores - Live Scores                              40
# 3D Blue Glass Water Keyboard Theme                   40
# 3D Color Pixel by Number - Sandbox Art Coloring      40
# 3D Live Neon Weed Launcher                           40
# ...

# %%
df_copy.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
df_copy['Translated_Review'].unique()
# Out:
# array(['I like eat delicious food. That\'s I\'m cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"',
#        'This help eating healthy exercise regular basis', nan, ...,
#        'Dumb app, I wanted post property rent give option. Website work. Waste time space phone.',
#        'I property business got link SMS happy performance still guys need raise bar guys Cheers',
#        'Useless app, I searched flats kondapur, Hyderabad . None number reachable I know flats unavailable would keep posts active'],
#       dtype=object)

# %%
df_copy.loc[df_copy['Translated_Review'].isna()].head()
# Out:
#                        App Translated_Review Sentiment  Sentiment_Polarity  \
# 2    10 Best Foods for You               NaN       NaN                 NaN
# 7    10 Best Foods for You               NaN       NaN                 NaN
# 15   10 Best Foods for You               NaN       NaN                 NaN
# 102  10 Best Foods for You               NaN       NaN                 NaN
# 107  10 Best Foods for You               NaN       NaN                 NaN
#
#      Sentiment_Subjectivity
# 2                       NaN
# 7                       NaN
# 15                      NaN
# 102                     NaN
# 107                     NaN

# %%
df_copy.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
df_copy[df_copy['Sentiment_Polarity'].isna()]
# Out:
#                                App Translated_Review Sentiment  \
# 2            10 Best Foods for You               NaN       NaN
# 7            10 Best Foods for You               NaN       NaN
# 15           10 Best Foods for You               NaN       NaN
# 102          10 Best Foods for You               NaN       NaN
# 107          10 Best Foods for You               NaN       NaN
# ...                            ...               ...       ...
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 2                     NaN                     NaN
# 7                     NaN                     NaN
# 15                    NaN                     NaN
# ...

# %%
# Fill all null cells with the average 'Sentiment_Polarity' of all apps in the same Sentiment
df_copy['Sentiment_Polarity'] =df_copy.groupby('Sentiment')['Sentiment_Polarity'].transform(lambda x: x.fillna(x.mean()))

# %%
# Fill all null cells with the average 'Sentiment_Subjectivity' of all apps in the same Sentiment
df_copy['Sentiment_Subjectivity'] =df_copy.groupby('Sentiment')['Sentiment_Subjectivity'].transform(lambda x: x.fillna(x.mean()))

# %%
#Removing all the raows having Translated reviews as na
df_copy = df_copy.dropna(subset='Translated_Review')

# %%
df_copy[df_copy['Translated_Review'].isna()]
# Out:
#                                App Translated_Review Sentiment  \
# 2            10 Best Foods for You               NaN       NaN
# 7            10 Best Foods for You               NaN       NaN
# 15           10 Best Foods for You               NaN       NaN
# 102          10 Best Foods for You               NaN       NaN
# 107          10 Best Foods for You               NaN       NaN
# ...                            ...               ...       ...
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 2                     NaN                     NaN
# 7                     NaN                     NaN
# 15                    NaN                     NaN
# ...

# %%
df_copy.loc[(df_copy['Translated_Review'].isna()) & (df_copy['Sentiment'].isna())]
# Out:
#                                App Translated_Review Sentiment  \
# 2            10 Best Foods for You               NaN       NaN
# 7            10 Best Foods for You               NaN       NaN
# 15           10 Best Foods for You               NaN       NaN
# 102          10 Best Foods for You               NaN       NaN
# 107          10 Best Foods for You               NaN       NaN
# ...                            ...               ...       ...
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 2                     NaN                     NaN
# 7                     NaN                     NaN
# 15                    NaN                     NaN
# ...

# %%
df_copy
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
df_copy.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
df_copy.describe(include='all')
# Out:
#                App Translated_Review Sentiment  Sentiment_Polarity  \
# count        37432             37427     37432        37432.000000
# unique         865             27994         3                 NaN
# top     Bowmasters              Good  Positive                 NaN
# freq           312               247     23998                 NaN
# mean           NaN               NaN       NaN            0.182146
# std            NaN               NaN       NaN            0.351301
# min            NaN               NaN       NaN           -1.000000
# 25%            NaN               NaN       NaN            0.000000
# 50%            NaN               NaN       NaN            0.150000
# 75%            NaN               NaN       NaN            0.400000
# max            NaN               NaN       NaN            1.000000
#
#         Sentiment_Subjectivity
# count             37432.000000
# unique                     NaN
# top                        NaN
# freq                       NaN
# ...

# %%
df_copy.isnull().sum()
# Out:
# App                       0
# Translated_Review         5
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
df_copy.loc[df_copy['Translated_Review'].isna()]
# Out:
#                                              App Translated_Review Sentiment  \
# 268                                         11st               NaN   Neutral
# 15048        Birds Sounds Ringtones & Wallpapers               NaN   Neutral
# 22092             Calorie Counter - MyFitnessPal               NaN   Neutral
# 31623                                  DC Comics               NaN   Neutral
# 52500  Garden Photo Frames - Garden Photo Editor               NaN   Neutral
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 268                   0.0                     0.0
# 15048                 0.0                     0.0
# 22092                 0.0                     0.0
# 31623                 0.0                     0.0
# 52500                 0.0                     0.0

# %%
df.loc[df['App']=='I am rich']
# Out:
# Empty DataFrame
# Columns: [App, Translated_Review, Sentiment, Sentiment_Polarity, Sentiment_Subjectivity]
# Index: []

# %%
df.groupby('App').mean().reset_index()
# Out:
#                                                  App  Sentiment_Polarity  \
# 0                              10 Best Foods for You            0.470733
# 1                   104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室            0.392405
# 2                                               11st            0.181294
# 3                         1800 Contacts - Lens Store            0.318145
# 4                    1LINE – One Line with One Touch            0.196290
# ...                                              ...                 ...
# 1069  Hotspot Shield Free VPN Proxy & Wi-Fi Security            0.251765
# 1070                                         Hotstar            0.038178
# 1071                  Hotwire Hotel & Car Rental App            0.187029
# 1072                  Housing-Real Estate & Property           -0.021427
# 1073                     Houzz Interior Design Ideas                 NaN
#
#       Sentiment_Subjectivity
# 0                   0.495455
# 1                   0.545516
# ...

# %%
df.drop_duplicates()
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
# 64236     Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
df_copy
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...
